# %% [markdown]
# # Read in LGA list and clean up for use in google api loops

# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import time
from bs4 import BeautifulSoup as bs
# Google API Key
from config import gkey

#file path to saved csv dataframe
file = '../Raw_Data/Vic-LGA-List.csv'

# %%
#bring csv file in as pd dataframe
council_city_df = pd.read_csv(file, encoding="ISO-8859-1")
council_city_df
# Out:
#                     ï»¿COUNCIL              CEO NAME       DEAR CEO  \
# 0         Alpine Shire Council       Mr Charlie Bird        Mr Bird
# 1    Ararat Rural City Council       Dr Tim Harrison    Dr Harrison
# 2        Ballarat City Council         Ms Janet Dore        Ms Dore
# 3         Banyule City Council   Ms Allison Beckwith    Ms Beckwith
# 4     Bass Coast Shire Council         Ms Ali Wastie      Ms Wastie
# ..                         ...                   ...            ...
# 74        Wodonga City Council         Mr Mark Dixon       Mr Dixon
# 75        Wyndham City Council      Ms Kelly Grigsby     Ms Grigsby
# 76          Yarra City Council  Ms Vijaya Vaidyanath  Ms Vaidyanath
# 77  Yarra Ranges Shire Council         Ms Tammi Rose        Ms Rose
# 78  Yarriambiack Shire Council      Ms Jessie Holmes      Ms Holmes
#
#                   CEO TITLE          MAYOR NAME    DEAR MAYOR MAYOR TITLE  \
# 0   Chief Executive Officer      Cr Peter Roper      Cr Roper       Mayor
# 1   Chief Executive Officer     Cr Jo Armstrong  Cr Armstrong       Mayor
# 2   Chief Executive Officer       Cr Ben Taylor     Cr Taylor       Mayor
# 3   Chief Executive Officer  Cr Alison Champion   Cr Champion       Mayor
# 4   Chief Executive Officer    Cr Brett Tessari    Cr Tessari       Mayor
# ..                      ...                 ...           ...         ...
# 74  Chief Executive Officer     Cr Anna Speedie    Cr Speedie       Mayor
# 75  Chief Executive Officer    Cr Josh Gilligan   Cr Gilligan       Mayor
# 76  Chief Executive Officer    Cr Misha Coleman    Cr Coleman       Mayor
# 77  Chief Executive Officer  Cr Richard Higgins    Cr Higgins       Mayor
# 78  Chief Executive Officer    Cr Graeme Massey     Cr Massey       Mayor
#
#         POSTAL  POSTAL SUBURB  PCODE                  DX  \
# 0   PO Box 139         BRIGHT   3741
# 1   PO Box 246         ARARAT   3377
# 2   PO Box 655       BALLARAT   3353
# 3    PO Box 94  GREENSBOROUGH   3088    DX 97904 Ivanhoe
# 4   PO Box 118      WONTHAGGI   3995  DX 34903 Wonthaggi
# ..         ...            ...    ...                 ...
# 74  PO Box 923        WODONGA   3689
# 75  PO Box 197       WERRIBEE   3030
# 76  PO Box 168       RICHMOND   3121   DX 30205 Richmond
# 77  PO Box 105       LILYDALE   3140   DX 34051 Lilydale
# 78  PO Box 243  WARRACKNABEAL   3393
#
#                       ADDRESS   SUBURB/ TOWN  CODE  \
# 0           Great Alpine Road         BRIGHT  3741
# 1           59 Vincent Street         ARARAT  3377
# 2   25 Armstrong Street South       BALLARAT  3350
# 3           1 Flintoff Street  GREENSBOROUGH  3088
# 4           76 McBride Avenue      WONTHAGGI  3995
# ..                        ...            ...   ...
# 74          104 Hovell Street        WODONGA  3690
# 75         45 Princes Highway       WERRIBEE  3030
# 76            333 Bridge Road       RICHMOND  3121
# 77            Anderson Street       LILYDALE  3140
# 78             34 Lyle Street  WARRACKNABEAL  3393
#
#                                   TEL           FAX  \
# 0                           5755 0555     5755 1811
# 1                           5355 0200     5352 1695
# 2                           5320 5500     5333 4061
# 3                           9490 4222     9499 9475
# 4   1300 BCOAST (226278) or 5671 2211     5671 2222
# ..                                ...           ...
# 74                       02 6022 9300  02 6022 9322
# 75                          9742 0777     9741 6237
# 76                          9205 5555
# 77                       1300 368 333     9735 4249
# 78                          5398 0100     5398 2502
#
#                              EMAIL                    WWW SITE
# 0      info@alpineshire.vic.gov.au  www.alpineshire.vic.gov.au
# 1        council@ararat.vic.gov.au       www.ararat.vic.gov.au
# 2         info@ballarat.vic.gov.au     www.ballarat.vic.gov.au
# 3     enquiries@banyule.vic.gov.au      www.banyule.vic.gov.au
# 4   basscoast@basscoast.vic.gov.au    www.basscoast.vic.gov.au
# ..                             ...                         ...
# 74         info@wodonga.vic.gov.au      www.wodonga.vic.gov.au
# 75         mail@wyndham.vic.gov.au      www.wyndham.vic.gov.au
# 76       info@yarracity.vic.gov.au    www.yarracity.vic.gov.au
# 77     mail@yarraranges.vic.gov.au  www.yarraranges.vic.gov.au
# 78    info@yarriambiack.vic.gov.au     yarriambiack.vic.gov.au
#
# [79 rows x 18 columns]

# %%
print('The number of Local Government Areas (councils) in Vic is: '+str(len(council_city_df)))
# Out:
# The number of Local Government Areas (councils) in Vic is: 79

# %%
# get list of column headings for cleaning up df
council_city_df.columns.unique()
# Out:
# Index(['ï»¿COUNCIL', 'CEO NAME', 'DEAR CEO', 'CEO TITLE', 'MAYOR NAME',
#        'DEAR MAYOR', 'MAYOR TITLE', 'POSTAL', 'POSTAL SUBURB', 'PCODE', 'DX',
#        'ADDRESS', 'SUBURB/ TOWN', 'CODE', 'TEL', 'FAX', 'EMAIL', 'WWW SITE'],
#       dtype='object')

# %%
# clean council_city_df to have just the columns wanted
council_city_df=council_city_df.drop(['CEO NAME', 'DEAR CEO', 'CEO TITLE', 
                                      'MAYOR NAME','DEAR MAYOR', 'MAYOR TITLE', 
                                      'POSTAL', 'POSTAL SUBURB', 'PCODE', 'DX',
                                      'ADDRESS','TEL', 'FAX', 'EMAIL'], axis=1)
# re-name council column
council_city_df = council_city_df.rename(columns={"ï»¿COUNCIL": "COUNCIL"})
council_city_df
# Out:
#                        COUNCIL   SUBURB/ TOWN  CODE  \
# 0         Alpine Shire Council         BRIGHT  3741
# 1    Ararat Rural City Council         ARARAT  3377
# 2        Ballarat City Council       BALLARAT  3350
# 3         Banyule City Council  GREENSBOROUGH  3088
# 4     Bass Coast Shire Council      WONTHAGGI  3995
# ..                         ...            ...   ...
# 74        Wodonga City Council        WODONGA  3690
# 75        Wyndham City Council       WERRIBEE  3030
# 76          Yarra City Council       RICHMOND  3121
# 77  Yarra Ranges Shire Council       LILYDALE  3140
# 78  Yarriambiack Shire Council  WARRACKNABEAL  3393
#
#                       WWW SITE
# 0   www.alpineshire.vic.gov.au
# 1        www.ararat.vic.gov.au
# 2      www.ballarat.vic.gov.au
# 3       www.banyule.vic.gov.au
# 4     www.basscoast.vic.gov.au
# ..                         ...
# 74      www.wodonga.vic.gov.au
# 75      www.wyndham.vic.gov.au
# 76    www.yarracity.vic.gov.au
# 77  www.yarraranges.vic.gov.au
# 78     yarriambiack.vic.gov.au
#
# [79 rows x 4 columns]

# %%
# remove melb from df
cities_df_xmelb = cities_df.drop([1977])
cities_df_xmelb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2111c6b05b4e> in <module>
#       1 # remove melb from df
# ----> 2 cities_df_xmelb = cities_df.drop([1977])
#       3 cities_df_xmelb
#
# NameError: name 'cities_df' is not defined

# %%
print(len(cities_df_xmelb))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-de47a16b746d> in <module>
# ----> 1 print(len(cities_df_xmelb))
#
# NameError: name 'cities_df_xmelb' is not defined

# %%
# make city list
cities = council_city_df["SUBURB/ TOWN"].tolist()
print(cities)
# Out:
# ['BRIGHT', 'ARARAT', 'BALLARAT', 'GREENSBOROUGH', 'WONTHAGGI', 'DROUIN', 'SANDRINGHAM', 'BENALLA', 'CAMBERWELL', 'SUNSHINE', 'WYCHEPROOF', 'ECHUCA', 'OFFICER', 'NARRE WARREN', 'MARYBOROUGH', 'COLAC', 'CAMPERDOWN', 'PRESTON', 'BAIRNSDALE', 'FRANKSTON', 'KERANG', 'CAULFIELD SOUTH', 'PORTLAND', 'BANNOCKBURN', 'BENDIGO', 'DANDENONG', 'GEELONG', 'SHEPPARTON', 'DAYLESFORD', 'NHILL', 'ALTONA', 'HORSHAM', 'BROADMEADOWS', 'BEECHWORTH', 'CHELTENHAM', 'WANTIRNA SOUTH', 'MORWELL', 'WEDDERBURN', 'KYNETON', 'DONCASTER', 'MANSFIELD', 'FOOTSCRAY', 'RINGWOOD', 'MELBOURNE', 'MELTON', 'MILDURA', 'BROADFORD', 'COBRAM', 'GLEN WAVERLEY', 'MOONEE PONDS', 'BALLAN', 'COBURG', 'ROSEBUD', 'CASTLEMAINE', 'PORT FAIRY', 'ALEXANDRA', 'GREENSBOROUGH', 'STAWELL', 'ST KILDA', 'BEAUFORT', 'QUEENSCLIFF', 'LEONGATHA', 'HAMILTON', 'MALVERN', 'EUROA', 'TORQUAY', 'SWAN HILL', 'TALLANGATTA', 'WANGARATTA', 'WARRNAMBOOL', 'SALE', 'EDENHOPE', 'NUNAWADING', 'SOUTH MORANG', 'WODONGA', 'WERRIBEE', 'RICHMOND', 'LILYDALE', 'WARRACKNABEAL']

# %%
cities_list = np.array(cities)
print(cities_list)
# Out:
# ['BRIGHT' 'ARARAT' 'BALLARAT' 'GREENSBOROUGH' 'WONTHAGGI' 'DROUIN'
#  'SANDRINGHAM' 'BENALLA' 'CAMBERWELL' 'SUNSHINE' 'WYCHEPROOF' 'ECHUCA'
#  'OFFICER' 'NARRE WARREN' 'MARYBOROUGH' 'COLAC' 'CAMPERDOWN' 'PRESTON'
#  'BAIRNSDALE' 'FRANKSTON' 'KERANG' 'CAULFIELD SOUTH' 'PORTLAND'
#  'BANNOCKBURN' 'BENDIGO' 'DANDENONG' 'GEELONG' 'SHEPPARTON' 'DAYLESFORD'
#  'NHILL' 'ALTONA' 'HORSHAM' 'BROADMEADOWS' 'BEECHWORTH' 'CHELTENHAM'
#  'WANTIRNA SOUTH' 'MORWELL' 'WEDDERBURN' 'KYNETON' 'DONCASTER' 'MANSFIELD'
#  'FOOTSCRAY' 'RINGWOOD' 'MELBOURNE' 'MELTON' 'MILDURA' 'BROADFORD'
#  'COBRAM' 'GLEN WAVERLEY' 'MOONEE PONDS' 'BALLAN' 'COBURG' 'ROSEBUD'
#  'CASTLEMAINE' 'PORT FAIRY' 'ALEXANDRA' 'GREENSBOROUGH' 'STAWELL'
#  'ST KILDA' 'BEAUFORT' 'QUEENSCLIFF' 'LEONGATHA' 'HAMILTON' 'MALVERN'
#  'EUROA' 'TORQUAY' 'SWAN HILL' 'TALLANGATTA' 'WANGARATTA' 'WARRNAMBOOL'
#  'SALE' 'EDENHOPE' 'NUNAWADING' 'SOUTH MORANG' 'WODONGA' 'WERRIBEE'
#  'RICHMOND' 'LILYDALE' 'WARRACKNABEAL']

# %% [markdown]
# # Get Tourist Attractions using loop through cities and calling google api

# %%
# use google api to search things to do for each city

#lists to append to
name_ta = []
address_ta = []
rating_ta = []
city_ta = []
city_searched = []
for city in cities_list:
    citi = city
    city_ta.append(citi)
    my_phrase = f"tourist attraction establishment in {city} VIC, AU"
    target_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
    "query": my_phrase,
    "key": gkey
    }
    response = requests.get(target_url, params)
    to_dos = response.json()
    counter = 0
    # print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
    print("----------------------")
    #print(response.url)
    #print(json.dumps(to_dos, indent=4, sort_keys=True))
    for do in to_dos["results"]:
        counter += 1
        try:
            print("-------------------")
            print(f'{citi}')
            city_searched.append(citi)
            called = do["name"]
            locate = do["formatted_address"]
            rated = do["rating"]
            if(called, locate and rated):
                print("-------------------")
                name_ta.append(called)
                print(called)
                address_ta.append(locate)
                print(locate)
                rating_ta.append(rated)
                print(rated)
        except:
            print('not found')           
    
    if counter == 20:
        time.sleep(1.01)
        counter = 0
# Out:
# mond St, Sale VIC 3850, Australia
# 0
# -------------------
# SALE
# -------------------
# Gippsland Armed Forces Museum
# Lyon Cres, Fulham VIC 3851, Australia
# 4.5
# -------------------
# SALE
# -------------------
# Sale and Districts Aeromodellers Club
# Centre Rd, Sale VIC 3850, Australia
# 4.9
# -------------------
# SALE
# -------------------
# Sale Garden Supplies & Mini-Mix Concrete
# 40-42 Princes Hwy, Sale VIC 3850, Australia
# 4.2
# -------------------
# SALE
# -------------------
# Gippsland Vehicle Collection
# 1 Maffra-Sale Rd, Maffra VIC 3860, Australia
# 4.6
# ----------------------
# -------------------
# EDENHOPE
# -------------------
# Edenhope Information Centre
# 96 Elizabeth St, Edenhope VIC 3318, Australia
# 4.8
# -------------------
# EDENHOPE
# -------------------
# Edenhope N.F.R.
# Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Sheepwash, Edenhope W.R
# Kaniva-Edenhope Rd, Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Kadnook Bushland Reserve
# Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Edenhope Aerodrome Bushland Reserve
# Jennings Rd, Edenhope VIC 3318, Australia
# 2
# -------------------
# EDENHOPE
# -------------------
# Kurrayah Swamp W.R
# Powers Creek Rd, Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Lions Park
# Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Lake Kemi Kemi W.R
# Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Parsons (Collins) Lake L.R
# Sullivans Rd, Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Edenhope Lakeside Tourist Park
# Lake St, Edenhope VIC 3318, Australia
# 4.5
# -------------------
# EDENHOPE
# -------------------
# Yallakar I20 Bushland Reserve
# Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Hurleys Bank W.R.
# Scrubby Lake Rd, Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Awonga I19 Bushland Reserve
# Sims Rd, Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Edenhope Antiques
# 162 Elizabeth St, Edenhope VIC 3318, Australia
# 4.1
# -------------------
# EDENHOPE
# -------------------
# Yallakar I22 Bushland Reserve
# Eric Sambells Road, Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Assiste Swamp Wildlife Reserve
# Powers Creek Rd, Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# Lake Wallace
# Lake Wallace, Edenhope VIC 3318, Australia
# 4.8
# -------------------
# EDENHOPE
# -------------------
# Lake Ratzcastle Lake Reserve
# Edenhope-Goroke Rd, Karnak VIC 3401, Australia
# 3.7
# -------------------
# EDENHOPE
# -------------------
# Apex Park
# 40 Elizabeth St, Edenhope VIC 3318, Australia
# 0
# -------------------
# EDENHOPE
# -------------------
# West Wimmera Shire Council
# 49 Elizabeth St, Edenhope VIC 3318, Australia
# 0
# ----------------------
# -------------------
# NUNAWADING
# -------------------
# Tunstall Park
# Nunawading VIC 3131, Australia
# 4.3
# -------------------
# NUNAWADING
# -------------------
# Lindsay Avenue Linear Reserve
# 43B Springvale Rd, Nunawading VIC 3131, Australia
# 3.5
# -------------------
# NUNAWADING
# -------------------
# Jubilee Road Reserve
# 39 Jubilee St, Nunawading VIC 3131, Australia
# 4.7
# -------------------
# NUNAWADING
# -------------------
# Nangnak Garden
# Nunawading VIC 3131, Australia
# 4.5
# -------------------
# NUNAWADING
# -------------------
# Nicoll Park
# Nunawading VIC 3131, Australia
# 4.4
# -------------------
# NUNAWADING
# -------------------
# Mullum Mullum Park
# Donvale VIC 3111, Australia
# 4.5
# -------------------
# NUNAWADING
# -------------------
# Koonung Creek Trail
# Koonung Creek Trail, Nunawading VIC 3131, Australia
# 5
# -------------------
# NUNAWADING
# -------------------
# Charles Rooks Reserve
# Nunawading VIC 3131, Australia
# 3.9
# -------------------
# NUNAWADING
# -------------------
# Box Hill to Ringwood shared use path
# Unnamed Road, Nunawading VIC 3131, Australia
# 5
# -------------------
# NUNAWADING
# -------------------
# Oxford Street Reserve
# 17 Oxford St, Nunawading VIC 3131, Australia
# 4
# -------------------
# NUNAWADING
# -------------------
# Eastern Freeway Linear Reserve
# Nunawading VIC 3131, Australia
# 4.6
# -------------------
# NUNAWADING
# -------------------
# Feiglin Park
# Nunawading VIC 3131, Australia
# 4
# -------------------
# NUNAWADING
# -------------------
# Cow Playground
# 1 Wren Cl, Nunawading VIC 3131, Australia
# 4.3
# -------------------
# NUNAWADING
# -------------------
# BOUNCEinc Blackburn
# 22 Joseph St, Blackburn North VIC 3130, Australia
# 4.5
# -------------------
# NUNAWADING
# -------------------
# Ringwood Clocktower
# 104A Maroondah Hwy, Ringwood VIC 3134, Australia
# 4
# -------------------
# NUNAWADING
# -------------------
# Blackburn Lake - Bench
# 28 Lake Rd, Blackburn VIC 3130, Australia
# 4
# -------------------
# RICHMOND
# -------------------
# Brogan's Way
# 61 North St, Richmond VIC 3121, Australia
# 4.8
# -------------------
# RICHMOND
# -------------------
# McConchie Reserve
# Mary St, Melbourne VIC 3121, Australia
# 4.2
# -------------------
# RICHMOND
# -------------------
# Kings Domain
# Alexandra Ave, Melbourne VIC 3004, Australia
# 4.6
# -------------------
# RICHMOND
# -------------------
# Yarra Bank Reserve
# Yarra Bank Reserve, 44 Creswick St, Hawthorn VIC 3122, Australia
# 4.6
# -------------------
# RICHMOND
# -------------------
# Royal Botanic Gardens Victoria - Melbourne Gardens
# Birdwood Ave, South Yarra VIC 3141, Australia
# 4.8
# -------------------
# RICHMOND
# -------------------
# Bradman Statue
# East Melbourne VIC 3002, Australia
# 3.6
# -------------------
# RICHMOND
# -------------------
# Golden Square Bicentennial Park
# Madden Grove, Burnley VIC 3121, Australia
# 4.3
# -------------------
# RICHMOND
# -------------------
# Como House & Garden
# Williams Rd &, Lechlade Ave, South Yarra VIC 3141, Australia
# 4.4
# -------------------
# RICHMOND
# -------------------
# Norm Smith Monument
# Jolimont Station, Wellington Cres, East Melbourne VIC 3002, Australia
# 0
# -------------------
# RICHMOND
# -------------------
# Carlton Brewhouse
# 24 Thompson St, Abbotsford VIC 3067, Australia
# 4.7
# -------------------
# RICHMOND
# -------------------
# Cooks' Cottage
# Fitzroy Gardens, Wellington Parade, East Melbourne VIC 3002, Australia
# 4.3
# ----------------------
# -------------------
# LILYDALE
# -------------------
# Lillydale Lake Playground
# 435 Swansea Rd, Lilydale VIC 3140, Australia
# 4.5
# -------------------
# LILYDALE
# -------------------
# Yarra Ranges Regional Museum
# 35-37 Castella St, Lilydale VIC 3140, Australia
# 4.5
# -------------------
# LILYDALE
# -------------------
# Hull Road Wetlands
# Hull Rd, Lilydale VIC 3140, Australia
# 4.5
# -------------------
# LILYDALE
# -------------------
# Old Lilydale Shortcut
# Lilydale VIC 3140, Australia
# 3.9
# -------------------
# LILYDALE
# -------------------
# Lilydale Lake Bench 1
# 435E Swansea Rd, Lilydale VIC 3140, Australia
# 0
# -------------------
# LILYDALE
# -------------------
# Bellbird Park @ Lilydale Lake
# 435 Swansea Rd, Lilydale VIC 3140, Australia
# 4.4
# -------------------
# LILYDALE
# -------------------
# Olinda Creek Trail
# Lilydale VIC 3140, Australia
# 4.1
# -------------------
# LILYDALE
# -------------------
# Quinn Reserve
# 99 Quinn Cres, Mount Evelyn VIC 3796, Australia
# 4.3
# -------------------
# LILYDALE
# -------------------
# Poyner Reserve
# 74 Cave Hill Rd, Lilydale VIC 3140, Australia
# 3.7
# -------------------
# LILYDALE
# -------------------
# RealPestControlLilydal
# 33-45 Hutchinson St, Lilydale VIC 3140, Australia
# 0
# -------------------
# LILYDALE
# -------------------
# Melba Park
# Market St, Lilydale VIC 3140, Australia
# 4.3
# -------------------
# LILYDALE
# -------------------
# Gateway Reserve
# Unnamed Road, Lilydale VIC 3140, Australia
# 4.1
# -------------------
# LILYDALE
# -------------------
# Lions Park
# 208 Main St, Lilydale VIC 3140, Australia
# 4.5
# -------------------
# LILYDALE
# -------------------
# Lilydale Memorial Park
# 126-128 Victoria Rd, Lilydale VIC 3140, Australia
# 4.6
# -------------------
# LILYDALE
# -------------------
# Lakeview Reserve
# 39 The Ridge, Lilydale VIC 3140, Australia
# 0
# -------------------
# LILYDALE
# -------------------
# Soilinspector
# 29 Mangans Rd, Lilydale VIC 3140, Australia
# 4.7
# -------------------
# LILYDALE
# -------------------
# Helen's Hill Estate
# 16 Ingram Rd, Lilydale VIC 3140, Australia
# 4.2
# -------------------
# LILYDALE
# -------------------
# Mont De Lancey Historic Homestead
# 71 Wellington Rd, Wandin North VIC 3139, Australia
# 4.5
# -------------------
# LILYDALE
# -------------------
# Yarra Ranges Tourism
# Lilydale Lakeside Campus, Building LA, Room 260, 1 Jarlo Drive, Lilydale VIC 3140, Australia
# 4.5
# -------------------
# LILYDALE
# -------------------
# Old Pound Reserve
# Erldunda Ct, Lilydale VIC 3140, Australia
# 4
# ----------------------
# -------------------
# WARRACKNABEAL
# -------------------
# Warracknabeal Tourist Information Centre
# 119 Scott St, Warracknabeal VIC 3393, Australia
# 4.1
# -------------------
# WARRACKNABEAL
# -------------------
# Wheatlands Agricultural Museum
# 34 Henty Hwy, Warracknabeal VIC 3393, Australia
# 4.8
# -------------------
# WARRACKNABEAL
# -------------------
# Historical Centre
# 81 Scott St, Warracknabeal VIC 3393, Australia
# 5
# -------------------
# WARRACKNABEAL
# -------------------
# GrainCorp Sheep Hills Silo Art
# 445 Sheep Hills-Minyip Rd, Sheep Hills VIC 3392, Australia
# 4.7
# -------------------
# WARRACKNABEAL
# -------------------
# Warracknabeal Racecourse
# 52 Henty Hwy, Warracknabeal VIC 3393, Australia
# 4.4
# -------------------
# WARRACKNABEAL
# -------------------
# Warracknabeal Caravan Park
# Lyle St, Warracknabeal VIC 3393, Australia
# 4
# -------------------
# WARRACKNABEAL
# -------------------
# Warracknabeal Herald
# 89 Scott St, Warracknabeal VIC 3393, Australia
# 4
# -------------------
# WARRACKNABEAL
# -------------------
# Warracknabeal Leisure Centre
# 31 Anderson St, Warracknabeal VIC 3393, Australia
# 4.2
# -------------------
# WARRACKNABEAL
# -------------------
# Kellalac Bushland Reserve
# Mellis Rd, Sheep Hills VIC 3393, Australia
# 0
# -------------------
# WARRACKNABEAL
# -------------------
# Yarriambiack Shire Council-Municipal Office
# 34 Lyle St, Warracknabeal VIC 3393, Australia
# 3
# -------------------
# WARRACKNABEAL
# -------------------
# Warrack Motel
# 2 Lyle St, Warracknabeal VIC 3393, Australia
# 3.8
# -------------------
# WARRACKNABEAL
# -------------------
# Minyip Bushland Reserve
# Donald-Murtoa Rd, Minyip VIC 3392, Australia
# 3.8
# -------------------
# WARRACKNABEAL
# -------------------
# Warracknabeal Neighbourhood House & Learning Centre Inc.
# 2 Cox St, Warracknabeal VIC 3393, Australia
# 0
# -------------------
# WARRACKNABEAL
# -------------------
# Australia Post - Warracknabeal LPO
# 107 Scott St, Warracknabeal VIC 3393, Australia
# 0
# -------------------
# WARRACKNABEAL
# -------------------
# Warracknabeal CFA
# 51 Devereux St, Warracknabeal VIC 3393, Australia
# 0
# -------------------
# WARRACKNABEAL
# -------------------
# Warracknabeal Primary School
# 5 Werrigar St, Warracknabeal VIC 3393, Australia
# 5
# -------------------
# WARRACKNABEAL
# -------------------
# Werrigar Roadhouse & Motel
# 213 Henty Hwy, Warracknabeal VIC 3393, Australia
# 4.3
# -------------------
# WARRACKNABEAL
# -------------------
# Warracknabeal Early Learning Centre
# 11 Werrigar St, Warracknabeal VIC 3393, Australia
# 0
# -------------------
# WARRACKNABEAL
# -------------------
# Lutheran Church of Australia
# 235 Scott St, Warracknabeal VIC 3393, Australia
# 3.6
# -------------------
# WARRACKNABEAL
# -------------------
# The Creekside Hotel Warracknabeal
# 4 Scott St, Warracknabeal VIC 3393, Australia
# 4.4

# %% [markdown]
# # Create and clean df from tourist attraction data gathered

# %%
print("Total returned Tourist Attractions: "+ str(len(name_ta)))
# Out:
# Total returned Tourist Attractions: 1560

# %%
#create a df from tourise attractions
tourist_site_df = pd.DataFrame(name_ta)
tourist_site_df["tourist_site_address"]= address_ta
tourist_site_df["tourist_site_rating"]= rating_ta
tourist_site_df["tourist_site_city"]= city_searched
# Rename column 0 tourist_sites_df
tourist_site_df = tourist_site_df.rename(columns={0: "tourist_site_name"})
tourist_site_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-5c436b13e4e2> in <module>
#       3 tourist_site_df["tourist_site_address"]= address_ta
#       4 tourist_site_df["tourist_site_rating"]= rating_ta
# ----> 5 tourist_site_df["tourist_site_city"]= city_searched
#       6 # Rename column 0 tourist_sites_df
#       7 tourist_site_df = tourist_site_df.rename(columns={0: "tourist_site_name"})
#
# ~\anaconda3\envs\webscraping\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\envs\webscraping\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# ~\anaconda3\envs\webscraping\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# -> 3768             value = sanitize_index(value, self.index)
#    3769             if not isinstance(value, (np.ndarray, Index)):
#    3770                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\envs\webscraping\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     746     if len(data) != len(index):
#     747         raise ValueError(
# --> 748             "Length of values "
#     749             f"({len(data)}) "
#     750             "does not match length of index "
#
# ValueError: Length of values (1561) does not match length of index (1560)

# %%
#drop duplicates in tourist_sites_df
tourist_site_xdbl_df=tourist_site_df.drop_duplicates(subset=['tourist_site_name', 'tourist_site_city'],keep='last')
tourist_site_xdbl_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-b2e0b087eaa3> in <module>
#       1 #drop duplicates in tourist_sites_df
# ----> 2 tourist_site_xdbl_df=tourist_site_df.drop_duplicates(subset=['tourist_site_name', 'tourist_site_city'],keep='last')
#       3 tourist_site_xdbl_df
#
# ~\anaconda3\envs\webscraping\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    5110
#    5111         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 5112         duplicated = self.duplicated(subset, keep=keep)
#    5113
#    5114         result = self[-duplicated]
#
# ~\anaconda3\envs\webscraping\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5246         diff = Index(subset).difference(self.columns)
#    5247         if not diff.empty:
# -> 5248             raise KeyError(diff)
#    5249
#    5250         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['tourist_site_city', 'tourist_site_name'], dtype='object')

# %%
# save csv of tourist sites
tourist_site_xdbl_df.to_csv("Cleaned_Data/tourist_sites.csv", encoding="utf-8", index=False)

# %% [markdown]
# # Get Resturants and cafes using loop through cities and calling google api

# %%
# Loop through each city to search for resturants and cafes 
#lists to append to
name_eat = []
address_eat = []
rating_eat =[]
city_search_eat = []
for city in cities_list:
    citi = city
    my_phrase = f"resturant cafe establishment in {city} VIC, AU"
    target_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
    "query": my_phrase,
    "key": gkey
    }
    response = requests.get(target_url, params)
    foodies = response.json()
    counter = 0
    # print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
    print("----------------------")
    #print(response.url)
    #print(json.dumps(to_dos, indent=4, sort_keys=True))
    for food in foodies["results"]:
        counter += 1
        try:
            print("-------------------")
            print(f'{citi}')
            city_search_eat.append(citi)
            city_eat = food
            print("-------------------")
            print(f'{counter}')
            print("-------------------")
            called = food["name"]
            locate = food["formatted_address"]
            rated = food["rating"]
            if(city_eat, called, locate and rated):
                print("-------------------")
                name_eat.append(called)
                print(called)
                address_eat.append(locate)
                print(locate)
                rating_eat.append(rated)
                print(rated)
        except:
            print('not found')            
    
    if counter == 20:
        time.sleep(1.01)
        counter = 0
# Out:
# lls St, Bright VIC 3741, Australia
# 4.7
# -------------------
# BRIGHT
# -------------------
# 20
# -------------------
# -------------------
# Dumu Balcony Cafe
# 4 Ireland St, Bright VIC 3741, Australia
# 4.3
# ----------------------
# -------------------
# ARARAT
# -------------------
# 1
# -------------------
# -------------------
# Sicilians Bar & Restaurant
# 102 Barkly St, Ararat VIC 3377, Australia
# 4.1
# -------------------
# ARARAT
# -------------------
# 2
# -------------------
# -------------------
# Ararat Family Restaurant
# 8475 Western Hwy, Ararat VIC 3377, Australia
# 3.4
# -------------------
# ARARAT
# -------------------
# 3
# -------------------
# -------------------
# Taste Of Peking Chinese Restaurant Ararat
# 157 Barkly St, Ararat VIC 3377, Australia
# 3.6
# -------------------
# ARARAT
# -------------------
# 4
# -------------------
# -------------------
# Sede Cafe
# 96 Barkly St, Ararat VIC 3377, Australia
# 4.4
# -------------------
# ARARAT
# -------------------
# 5
# -------------------
# -------------------
# Vines Cafe & Bar
# 74 Barkly St, Ararat VIC 3377, Australia
# 4.1
# -------------------
# ARARAT
# -------------------
# 6
# -------------------
# -------------------
# Foragers Cafe
# 82 Vincent St, Ararat VIC 3377, Australia
# 4.5
# -------------------
# ARARAT
# -------------------
# 7
# -------------------
# -------------------
# Waack's Bakery Ararat
# 168 Barkly St, Ararat VIC 3377, Australia
# 3.4
# -------------------
# ARARAT
# -------------------
# 8
# -------------------
# -------------------
# Gardens Lake Cafe
# Ararat VIC 3377, Australia
# 4.4
# -------------------
# ARARAT
# -------------------
# 9
# -------------------
# -------------------
# Candles Restaurant
# 79 Lambert St, Ararat VIC 3377, Australia
# 4.6
# -------------------
# ARARAT
# -------------------
# 10
# -------------------
# -------------------
# Domino's Pizza Ararat
# Safeway Complex, 3 & 4/1 Ingor St, Ararat VIC 3377, Australia
# 3.9
# -------------------
# ARARAT
# -------------------
# 11
# -------------------
# -------------------
# Fred & Bet's Cafe
# 101 Barkly St, Ararat VIC 3377, Australia
# 4.5
# -------------------
# ARARAT
# -------------------
# 12
# -------------------
# -------------------
# Ararat Noodle Bar
# 155 Barkly St, Ararat VIC 3377, Australia
# 4.2
# -------------------
# ARARAT
# -------------------
# 13
# -------------------
# -------------------
# Ararat Kebab House
# 82 Barkly St, Ararat VIC 3377, Australia
# 4.1
# -------------------
# ARARAT
# -------------------
# 14
# -------------------
# -------------------
# Fish on Barkly
# 262 Barkly St, Ararat VIC 3377, Australia
# 4.2
# -------------------
# ARARAT
# -------------------
# 15
# -------------------
# -------------------
# Waack's Bakery
# 172/168 Barkly St, Ararat VIC 3377, Australia
# 4
# -------------------
# ARARAT
# -------------------
# 16
# -------------------
# -------------------
# Ararat RSL
# 74-76 High St, Ararat VIC 3377, Australia
# 4.1
# -------------------
# ARARAT
# -------------------
# 17
# -------------------
# -------------------
# Khoon Thai Ararat
# 234-236 Barkly St, Ararat VIC 3377, Australia
# 4.9
# -------------------
# 4.3
# -------------------
# GREENSBOROUGH
# -------------------
# 15
# -------------------
# -------------------
# Greensborough crazy kebabs
# 183 Para Rd, Greensborough VIC 3088, Australia
# 4.1
# -------------------
# GREENSBOROUGH
# -------------------
# 16
# -------------------
# -------------------
# Flippin' Burgers
# Shop 301/25 Main St, Greensborough VIC 3088, Australia
# 4.5
# -------------------
# GREENSBOROUGH
# -------------------
# 17
# -------------------
# -------------------
# La Porchetta Greensborough
# 94 Main St, Greensborough VIC 3088, Australia
# 3.3
# -------------------
# GREENSBOROUGH
# -------------------
# 18
# -------------------
# -------------------
# Degani Greensborough
# GREENSBOROUGH PLAZA, 25 Main St, Greensborough VIC 3088, Australia
# 3.9
# -------------------
# GREENSBOROUGH
# -------------------
# 19
# -------------------
# -------------------
# The Groove Train Greensborough
# GREENSBOROUGH PLAZA, Shop 326, Level 3/25 Main St, Greensborough VIC 3088, Australia
# 3.5
# -------------------
# GREENSBOROUGH
# -------------------
# 20
# -------------------
# -------------------
# two young boys
# 2b/118 Main St, Greensborough VIC 3088, Australia
# 4.5
# ----------------------
# -------------------
# WONTHAGGI
# -------------------
# 1
# -------------------
# -------------------
# Souvanny Thai Restaurant
# 60 McBride Ave, Wonthaggi VIC 3995, Australia
# 3.9
# -------------------
# WONTHAGGI
# -------------------
# 2
# -------------------
# -------------------
# Dumpling Plaza Chinese Restaurant
# 26 McBride Ave, Wonthaggi VIC 3995, Australia
# 4.2
# -------------------
# WONTHAGGI
# -------------------
# 3
# -------------------
# -------------------
# Wonthaggi Club
# 16 McBride Ave, Wonthaggi VIC 3995, Australia
# 4.1
# -------------------
# WONTHAGGI
# -------------------
# 4
# -------------------
# -------------------
# Wonthaggi Hotel
# 2 McBride Ave, Wonthaggi VIC 3995, Australia
# 4.3
# -------------------
# WONTHAGGI
# -------------------
# 5
# -------------------
# -------------------
# BEANd
# Unit A/134/142 Graham St, Wonthaggi VIC 3995, Australia
# 4
# -------------------
# WONTHAGGI
# -------------------
# 6
# -------------------
# -------------------
# The Hicksborough General Store & Cafe
# 184 White Rd, North Wonthaggi VIC 3995, Australia
# 4.5
# -------------------
# WONTHAGGI
# -------------------
# 7
# -------------------
# -------------------
# The Coffee Collective
# 52/50 McBride Ave, Wonthaggi VIC 3995, Australia
# 4.3
# -------------------
# WONTHAGGI
# -------------------
# 8
# -------------------
# -------------------
# Wolf on Murray
# 1 Murray St, Wonthaggi VIC 3995, Australia
# 4.6
# -------------------
# WONTHAGGI
# -------------------
# 9
# -------------------
# -------------------
# Redgie's Cafe
# 1 Biggs Dr, Wonthaggi VIC 3995, Australia
# 4
# -------------------
# WONTHAGGI
# -------------------
# 10
# -------------------
# -------------------
# Rob's Fish and Chips, Burgers & Coffee Lounge
# 113-115 Graham St, Wonthaggi VIC 3995, Australia
# 4.7
# -------------------
# WONTHAGGI
# -------------------
# 11
# -------------------
# -------------------
# McDonald's Wonthaggi VIC
# Corner Billson and, Graham St, Wonthaggi VIC 3995, Australia
# 3.3
# -------------------
# WONTHAGGI
# -------------------
# 12
# -------------------
# -------------------
# The Caledonian Hotel
# 153/155 Graham St, Wonthaggi VIC 3995, Australia
# 4.2
# -------------------
# WONTHAGGI
# -------------------
# 13
# -------------------
# -------------------
# Youki's Japanese Take Away
# 46 McBride Ave, Wonthaggi VIC 3995, Australia
# 4.2
# -------------------
# WONTHAGGI
# -------------------
# 14
# -------------------
# -------------------
# Folks
# 132 Graham St, Wonthaggi VIC 3995, Australia
# 4.5
# -------------------
# WONTHAGGI
# -------------------
# 15
# -------------------
# -------------------
# Nyojo's Pizza
# 163 Graham St, Wonthaggi VIC 3995, Australia
# 4.3
# -------------------
# WONTHAGGI
# -------------------
# 16
# -------------------
# -------------------
# Kirrak Kiosk
# 2/13 Inverloch Rd, Wonthaggi VIC 3995, Australia
# 4.8
# -------------------
# WONTHAGGI
# -------------------
# 17
# -------------------
# -------------------
# Wonthaggi charcoal chicken
# 151A Graham St, Wonthaggi VIC 3995, Australia
# 3.5
# -------------------
# WONTHAGGI
# -------------------
# 18
# -------------------
# -------------------
# Ms. Betty's Cafe
# 17 Korumburra Rd, Wonthaggi VIC 3995, Australia
# 4.9
# -------------------
# WONTHAGGI
# -------------------
# 19
# -------------------
# -------------------
# Whistle Stop Bakery
# 28-30 McBride Ave, Wonthaggi VIC 3995, Australia
# 4
# -------------------
# WONTHAGGI
# -------------------
# 20
# -------------------
# -------------------
# Buon Appetito Pasta
# 170 Graham St, Wonthaggi VIC 3995, Australia
# 4.8
# ----------------------
# -------------------
# DROUIN
# -------------------
# 1
# -------------------
# -------------------
# Luciano's Bar and Restaurant
# 17a Princes Way, Drouin VIC 3818, Australia
# 4.2
# -------------------
# DROUIN
# -------------------
# 2
# -------------------
# -------------------
# Middels
# 3/94 Princes Way, Drouin VIC 3818, Australia
# 4.3
# -------------------
# DROUIN
# -------------------
# 3
# -------------------
# -------------------
# Drouin Thai Restaurant
# 1 Bank Pl, Drouin VIC 3818, Australia
# 4.3
# -------------------
# DROUIN
# -------------------
# 4
# -------------------
# -------------------
# The French Pear Cafe
# 83-85 Princes Way, Drouin VIC 3818, Australia
# 4.4
# -------------------
# DROUIN
# -------------------
# 5
# -------------------
# -------------------
# Drouin Family Hotel
# 65 Princes Way, Drouin VIC 3818, Australia
# 4.2
# -------------------
# DROUIN
# -------------------
# 6
# -------------------
# -------------------
# Drouin Gourmet Cafe
# 21 Princes Way, Drouin VIC 3818, Australia
# 4.5
# -------------------
# DROUIN
# -------------------
# 7
# -------------------
# -------------------
# Hong Kong Inn Resturant
# 51 Princes Way, Drouin VIC 3818, Australia
# 4.4
# -------------------
# DROUIN
# -------------------
# 8
# -------------------
# -------------------
# Albert's Kitchen
# 32 Albert Rd, Drouin VIC 3818, Australia
# 4.7
# -------------------
# DROUIN
# -------------------
# 9
# -------------------
# -------------------
# Drouin PizzaBurger Lounge
# 101 Princes Way, Drouin VIC 3818, Australia
# 3.8
# -------------------
# DROUIN
# -------------------
# 10
# -------------------
# -------------------
# Drouin Kebabs
# 137 Princes Way, Drouin VIC 3818, Australia
# 4.6
# -------------------
# DROUIN
# -------------------
# 11
# -------------------
# -------------------
# Isshin Japanese House Drouin
# 2/7 Bank Pl, Drouin VIC 3818, Australia
# 4.9
# -------------------
# DROUIN
# -------------------
# 12
# -------------------
# -------------------
# Cave Culture
# 49 Princes Way, Drouin VIC 3818, Australia
# 4.9
# -------------------
# DROUIN
# -------------------
# 13
# -------------------
# -------------------
# McDonald's Drouin
# 77 Young St, Drouin VIC 3818, Australia
# 3.5
# -------------------
# DROUIN
# -------------------
# 14
# -------------------
# -------------------
# Drouin Bakery & Cafe
# 32 Princes Way, Drouin VIC 3818, Australia
# 4.3
# -------------------
# DROUIN
# -------------------
# 15
# -------------------
# -------------------
# Gippy Fish N Chips
# 7 Bank Pl, Drouin VIC 3818, Australia
# 4.2
# -------------------
# DROUIN
# -------------------
# 16
# -------------------
# -------------------
# Drouin Fin & Feather
# 113 Princes Way, Drouin VIC 3818, Australia
# 4.1
# -------------------
# DROUIN
# -------------------
# 17
# -------------------
# -------------------
# Kims Kitchen (Order Online/ Delivery)
# 56 Commercial Pl, Drouin VIC 3818, Australia
# 3.6
# -------------------
# DROUIN
# -------------------
# 18
# -------------------
# -------------------
# Nick's Bakehouse
# 40 Princes Way, Drouin VIC 3818, Australia
# 4.1
# -------------------
# DROUIN
# -------------------
# 19
# -------------------
# -------------------
# 3 Ways Takeaway
# 29 Main S Rd, Drouin VIC 3818, Australia
# 4.4
# -------------------
# DROUIN
# -------------------
# 20
# -------------------
# -------------------
# Domino's Pizza Drouin
# Shop 4/149 Princes Hwy, Drouin VIC 3818, Australia
# 3.8
# ----------------------
# -------------------
# SANDRINGHAM
# -------------------
# 1
# -------------------
# -------------------
# Hobsons
# 19-21 Melrose St, Sandringham VIC 3191, Australia
# 4.2
# -------------------
# SANDRINGHAM
# -------------------
# 2
# -------------------
# -------------------
# Sandringham Yacht Club
# Jetty Rd, Sandringham VIC 3191, Australia
# 4.5
# -------------------
# SANDRINGHAM
# -------------------
# 3
# -------------------
# -------------------
# Baia Di Vino
# 1 Melrose St, Sandringham VIC 3191, Australia
# 4.8
# -------------------
# SANDRINGHAM
# -------------------
# 4
# -------------------
# -------------------
# The Sandy
# 118 Beach Rd, Sandringham VIC 3191, Australia
# 3.7
# -------------------
# SANDRINGHAM
# -------------------
# 5
# -------------------
# -------------------
# Barbalu's Pizza & Pasta
# 34 Bay Rd, Sandringham VIC 3191, Australia
# 4.2
# -------------------
# SANDRINGHAM
# -------------------
# 6
# -------------------
# -------------------
# Harbour View Restaurant
# Jetty Rd, Sandringham VIC 3191, Australia
# 4.3
# -------------------
# SANDRINGHAM
# -------------------
# 7
# -------------------
# -------------------
# Win Ho Chinese
# 89 Station St, Sandringham VIC 3191, Australia
# 4.4
# -------------------
# SANDRINGHAM
# -------------------
# 8
# -------------------
# -------------------
# Co. Cafe Sandringham
# 88 Station St, Sandringham VIC 3191, Australia
# 4.3
# -------------------
# SANDRINGHAM
# -------------------
# 9
# -------------------
# -------------------
# Le Phan Vietnamese Restaurant
# 5 Melrose St, Sandringham VIC 3191, Australia
# 4.3
# -------------------
# SANDRINGHAM
# -------------------
# 10
# -------------------
# -------------------
# Sook Sabai Thai Restaurant
# 84 Station St, Sandringham VIC 3191, Australia
# 4.2
# -------------------
# SANDRINGHAM
# -------------------
# 11
# -------------------
# -------------------
# Port of Call
# 7 Bay Rd, Sandringham VIC 3191, Australia
# 4.2
# -------------------
# SANDRINGHAM
# -------------------
# 12
# -------------------
# -------------------
# Limoncello
# 54 Station St, Sandringham VIC 3191, Australia
# 4.2
# -------------------
# SANDRINGHAM
# -------------------
# 13
# -------------------
# -------------------
# Syndicate Room.
# 254 Bay Rd, Sandringham VIC 3191, Australia
# 4.7
# -------------------
# SANDRINGHAM
# -------------------
# 14
# -------------------
# -------------------
# Full Turn Kitchen Bar
# 222 Bay Rd, Sandringham VIC 3191, Australia
# 4.6
# -------------------
# SANDRINGHAM
# -------------------
# 15
# -------------------
# -------------------
# Black Squirrel Cafe.
# 20 Bay Rd, Sandringham VIC 3191, Australia
# 4.2
# -------------------
# SANDRINGHAM
# -------------------
# 16
# -------------------
# -------------------
# Da Belcibo
# 355 Bluff Rd, Hampton VIC 3188, Australia
# 4.4
# -------------------
# SANDRINGHAM
# -------------------
# 17
# -------------------
# -------------------
# Ammos Greek Tavern
# 66 Station St, Sandringham VIC 3191, Australia
# 4.5
# -------------------
# SANDRINGHAM
# -------------------
# 18
# -------------------
# -------------------
# Y14 Japanese Seafood Kitchen & Bar
# 14 Bay Rd, Sandringham VIC 3191, Australia
# 4.5
# -------------------
# SANDRINGHAM
# -------------------
# 19
# -------------------
# -------------------
# True South
# 298 Beach Rd, Black Rock VIC 3193, Australia
# 4.4
# -------------------
# SANDRINGHAM
# -------------------
# 20
# -------------------
# -------------------
# Chives Cafe.
# 189 Bluff Rd, Sandringham VIC 3191, Australia
# 4.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-449529acf6ab> in <module>
#      45
#      46     if counter == 20:
# ---> 47         time.sleep(1.01)
#      48         counter = 0
#      49
#
# KeyboardInterrupt:

# %% [markdown]
# # Create and clean df from eatery data gathered

# %%
print("Total returned Eateries: "+ str(len(name_eat)))

# %%
#create a df from eateries
eateries_df = pd.DataFrame(name_eat)
eateries_df["eatery_address"]= address_eat
eateries_df["eatery_rating"]= rating_eat
eateries_df["eatery_city"]= city_search_eat
# Rename column 0 eateries_df
eateries_df = eateries_df.rename(columns={0: "eatery_name"})
eateries_df

# %%
#drop duplicates in eateries_df
eatery_xdbl_df=eateries_df.drop_duplicates(subset=['eatery_name', 'eatery_city'],keep='last')
eatery_xdbl_df

# %%
# save csv of eateries
eatery_xdbl_df.to_csv("Cleaned_Data/eateries.csv", encoding="utf-8", index=False)

# %% [markdown]
# # Get accommodation using loop through cities and calling google api

# %%
# Loop through each city to search for accommodation
#lists to append to
name_stay = []
address_stay = []
rating_stay =[]
city_search_stay = []

for city in cities_list:
    citi = city
    my_phrase = f"hotel motel accommodation near {city} VIC, AU"
    target_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
    "query": my_phrase,
    "key": gkey
    }
    response = requests.get(target_url, params)
    stays = response.json()
    counter = 0
    # print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
    print("----------------------")
    #print(response.url)
    #print(json.dumps(to_dos, indent=4, sort_keys=True))
    for stay in stays["results"]:
        counter += 1
        try:
            print("-------------------")
            print(f'{citi}')
            city_search_stay.append(citi)
            city_eat = stay
            print("-------------------")
            print(f'{counter}')
            print("-------------------")
            called = stay["name"]
            locate = stay["formatted_address"]
            rated = stay["rating"]
            if(city_eat, called, locate and rated):
                print("-------------------")
                name_stay.append(called)
                print(called)
                address_stay.append(locate)
                print(locate)
                rating_stay.append(rated)
                print(rated)
        except:
            print('not found')           
    
    if counter == 20:
        time.sleep(1.01)
        counter = 0

# %% [markdown]
# # Create and clean df from accommodation data gathered

# %%
print("Total returned Accommodation Options: "+ str(len(name_stay)))

# %%
#create a df from acommodation
accommodation_df = pd.DataFrame(name_stay)
accommodation_df["accommodation_address"]= address_stay
accommodation_df["accommodation_rating"]= rating_stay
accommodation_df["accommodation_city"]= city_search_stay
# Rename column 0 accommodation_df
accommodation_df = accommodation_df.rename(columns={0: "accommodation_name"})
accommodation_df

# %%
#drop duplicates in accommodation_df
accommodation_xdbl_df=accommodation_df.drop_duplicates(subset=['accommodation_name', 'accommodation_city'],keep='last')
accommodation_xdbl_df

# %%
# save csv of accommodation
accommodation_xdbl_df.to_csv("Cleaned_Data/lga_accommodation.csv", encoding="utf-8", index=False)

# %% [markdown]
# # Get average high temps for LGA cities

# %%
#loop through the cities to scrape climate history data for each city
weather= []
city_weather = []

for city in cities:
    #set base url
    url = f'https://www.eldersweather.com.au/climate-history/vic/{city}'
    # Retrieve page with the requests module
    response = requests.get(url)
    # Create a Beautiful Soup object
    soup = bs(response.text, 'html.parser')
    # set to find children in html table
    tables = soup.findChildren('table')
    my_table = tables[0]
    rows = my_table.findChildren(['th', 'tr'])
    for row in rows:
        cells = row.findChildren('td')       
        for cell in cells:
            value = cell.string
            value = value.replace('\n','')
            weather.append(value)
            city_weather.append(city)

# %%
print(len(weather))

# %%
obs_needed = 4108/79
obs_needed

# %%
obs = ['jan_max','feb_max','mar_max','apr_max','may_max','jun_max','jul_max','aug_max','sep_max',
       'oct_max','nov_max','dec_max','ann_max', 
       'jan_min','feb_min','mar_min','apr_min','may_min','jun_min','jul_min','aug_min','sep_min',
       'oct_min','nov_min','dec_min','ann_min',
       'jan_mm','feb_mm','mar_mm','apr_mm','may_mm','jun_mm','jul_mm','aug_mm','sep_mm','oct_mm',
       'nov_mm','dec_mm','ann_mm',
       'jan_rain_days','feb_rain_days','mar_rain_days','apr_rain_days','may_rain_days',
       'jun_rain_days','jul_rain_days','aug_rain_days','sep_rain_days','oct_rain_days',
       'nov_rain_days','dec_rain_days','ann_rain_days']

# %%
# loop to create enough sets of obs to match weather data to make df
obs_list=[]
counter = 0
for x in range(79):
    for ob in obs:
        obs_list.append(ob)

# %%
print(len(obs_list))

# %%
#create a weather obs df

#create a df from weather
av_weather_df = pd.DataFrame(obs_list)
av_weather_df['averages']= weather
av_weather_df['city']= city_weather

# Rename column 0 accommodation_df
av_weather_df = av_weather_df.rename(columns={0: "long-term_avg_obs"})
av_weather_df

# %%
# save csv of weather obs
av_weather_df.to_csv("Cleaned_Data/weather.csv", encoding="utf-8", index=False)
